# %%
from pprint import pprint

with open('inform.txt', 'r', encoding='utf-8') as fp:
    lines = map(lambda x: x.rstrip('\n'), fp.readlines())

# %%
print(*[(num, el) for num, el in enumerate(lines)], sep='\n')
# Out:
# (0, '36900498')
# (1, 'Автономная некоммерческая организация «Тамбовский волонтёрский корпус»')
# (2, '8')
# (3, '1800475')
# (4, 'Автономная некоммерческая организация «Центр развития физической культуры и спорта Тамбовской области «Олимпик»')
# (5, '12')
# (6, '1034648')
# (7, 'Автономная некоммерческая организация «Ресурсный центр по развитию добровольчества Тамбовской области»')
# (8, '12')
# (9, '2906211')
# (10, 'Автономная некоммерческая организация «Литературный Тамбов»')
# (11, '12')
# (12, '472283')
# (13, 'Автономная некоммерческая организация «Социальный центр «Александръ»')
# (14, '12')
# (15, '551000')
# (16, 'Автономная некоммерческая организация «Культурный Центр «Преображение»')
# (17, '12')
# (18, '2321000')
# (19, 'Автономная некоммерческая организация центр музыкального развития «Вектор»')
# (20, '12')
# (21, '489424')
# (22, 'Автономная некоммерческая организация развития молодёжи «Стимул»')
# (23, '8')
# (24, '1294668')
# ...

# %%
a = [1, 2, 3, 4, 5, 6] 
list(zip(a[::3], a[1::3], a[2::3]))
# Out:
# [(1, 2, 3), (4, 5, 6)]
